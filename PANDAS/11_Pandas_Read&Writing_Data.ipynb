# %%
import pandas as pd

# %%
df = pd.read_csv("Snippets/survey_results_public.csv", index_col = "Respondent") #for reading the data from the csv_file
schema_df = pd.read_csv("Snippets/survey_results_schema.csv", index_col = "Column")

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
#
#                            OpenSourcer  \
# Respondent
# 1                                Never
# 2              Less than once per year
# 3                                Never
# 4                                Never
# 5           Once a month or more often
#
#                                                    OpenSource  \
# Respondent
# 1           The quality of OSS and closed source software ...
# 2           The quality of OSS and closed source software ...
# 3           The quality of OSS and closed source software ...
# ...

# %%
filt = (df['Country'] == 'Nigeria')
india_df = df.loc[filt]
india_df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 205         I am not primarily a developer, but I write co...      Yes
# 348                            I am a developer by profession      Yes
# 365                               I code primarily as a hobby      Yes
# 688                            I am a developer by profession      Yes
# 885                            I am a developer by profession      Yes
# ...                                                       ...      ...
# 88812                          I am a developer by profession      Yes
# 88821                  I am a student who is learning to code       No
# 76960                                                     NaN       No
# 79616                                                     NaN       No
# 86806                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
#Writing to a csv
india_df.to_csv("Snippets/modified.csv")

# %%
#Write to tab delimited file.
india_df.to_csv("Snippets/modified.tsv", sep = "\t")

# %%
#Writing to excel.
#Istall packages like "pip install xlwt openpyxl xlrd"
india_df.to_excel("Snippets/modified.xlsx")

# %%
#reading from a excel.
test = pd.read_excel("Snippets/modified.xlsx", index_col="Respondent")

# %%
#Writing to json
india_df.to_json("Snippets/modified.json", orient="records", lines=True) #arguments Orient and lines for making the json file like a list.

# %%
#reading from json.
test_json = pd.read_json("Snippets/modified.json", orient="records", lines=True) #arguments Orient and lines for making the json file like a list.

# %%
test_json.head()
# Out:
#                                           MainBranch Hobbyist  \
# 0  I am not primarily a developer, but I write co...      Yes
# 1                     I am a developer by profession      Yes
# 2                        I code primarily as a hobby      Yes
# 3                     I am a developer by profession      Yes
# 4                     I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                            Less than once per year
# 1                            Less than once per year
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4                         Once a month or more often
#
#                                           OpenSource  \
# 0  OSS is, on average, of HIGHER quality than pro...
# 1  OSS is, on average, of LOWER quality than prop...
# 2  The quality of OSS and closed source software ...
# ...

# %%
#reading to SQL
#install certain packages like  SQLAlchemy& psycopg2-binary
from sqlalchemy import create_engine #allows us to connect to the database
import psycopg2

# %%
#engine = create_engine("URL to SQL database") 
#india_df_to_sql("Name of table", engine)
#india_df_to_sql("Name of table", engine, if_exists="replace")
#READING FROM AN SQL
#sql_df = pd.read_sql("Name of table", engine, index_col="Respondent")
#sql_df = pd.read_sql_query("SELECT * FROM Name of table", engine, index_col="Respondent") reading sql file using queries.

# %%
#reading from a url using json.
#post_df = pd.read_json("Url")

# %%
#THE END OF SERIES.

# %%
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 import seaborn
#
# File c:\users\above all omolere\envs\data_science\lib\site-packages\seaborn\__init__.py:2, in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File c:\users\above all omolere\envs\data_science\lib\site-packages\seaborn\rcmod.py:7, in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#      10 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#      11            "axes_style", "set_style", "plotting_context", "set_context",
#      12            "set_palette"]
#      15 _style_keys = [
#      16
#      17     "axes.facecolor",
#    (...)
# ...
